# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R

# %%
p = np.array([0,1,0])

# %%
r = R.from_euler("x",90,degrees=True)
r.as_matrix().round(2)

pr = r.apply(p)
pr.round(2)
# Out:
# array([0., 0., 1.])

# %%
fig = plt.figure()
ax = Axes3D(fig, auto_add_to_figure=False)

fig.add_axes(ax)
ax.scatter(0,0,0,color="k",s=80)
ax.scatter(p[0],p[1],p[2],color="blue",s=100)
ax.scatter(pr[0],pr[1],pr[2],color="red",s=100)
decora()

# %%
r = R.from_euler("xyz",[90,20,10],degrees=True)
r.as_matrix().round(2)
# Out:
# array([[ 0.93,  0.34,  0.17],
#        [ 0.16,  0.06, -0.98],
#        [-0.34,  0.94,  0.  ]])

# %%
r = R.from_euler("yzx",[20,10,90],degrees=True)
r.as_matrix().round(2)
# Out:
# array([[ 0.93, -0.17,  0.34],
#        [ 0.34,  0.  , -0.94],
#        [ 0.16,  0.98,  0.06]])

# %%
def decora():
    ax.set_xlabel('$x_1$ (x)')
    ax.set_ylabel('$x_2$ (y)')
    ax.set_zlabel('$x_3$ (z)')


    ax.quiver3D([0],[0],[0],[1],[0],[0] ,color="green",label="x")
    ax.quiver3D([0],[0],[0],[-1],[0],[0],color='g', linestyle="dashed")
    ax.quiver3D([0],[0],[0],[0],[1],[0],color="blue",label="y")
    ax.quiver3D([0],[0],[0],[0],[-1],[0],color="blue",linestyle="dashed")
    ax.quiver3D([0],[0],[0],[0],[0],[1],color="red",label="z")
    ax.quiver3D([0],[0],[0],[0],[0],[-1],color="red",linestyle="dashed")

    ax.set_xlim(-1,1)
    ax.set_ylim(-1,1)
    ax.set_zlim(-1,1)
    ax.legend()
