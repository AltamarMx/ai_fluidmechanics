# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np
import librosa.display as display
import glob as glob

# %%
y, sr = librosa.load("../music/divertimento.m4a", offset=60,duration=20)
fig, ax = plt.subplots(figsize=(16,4))
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
img = display.specshow(D, x_axis='time',
                               sr=sr, ax=ax,y_axis='fft_note')
ax.set(title='Divertimento')

# %%
diana = glob.glob('../music/*.wav')
diana

# %%
diana = glob.glob('../music/*.wav')
for archivo in diana:
    y, sr = librosa.load(archivo)
    fig, ax = plt.subplots(figsize=(12,12))
    D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
    img = display.specshow(D, x_axis='time',
                                   sr=sr, ax=ax,cmap='hot',y_axis='fft_note')
    # ax.set_ylim(0,2000)
    ax.set(title=archivo)

# %%
y, sr = librosa.load("../music/Escala_Do_M.wav")
fig, ax = plt.subplots(figsize=(16,4))
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
img = display.specshow(D, x_axis='time',
                               sr=sr, ax=ax,y_axis='fft_note')
ax.set(title='Escala Do Mayor')
# Out:
# [Text(0.5, 1.0, 'Escala Do Mayor')]

# %%
y, sr = librosa.load("../music/chromatic-amanecer.mp3")
fig, ax = plt.subplots(figsize=(16,4))
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
img = display.specshow(D, x_axis='time',
                               sr=sr, ax=ax,y_axis='linear')
ax.set_ylim(0,800)
ax.set(title='Chromatic Amanecer')
ax.grid()
# Out:
# /usr/local/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
y, sr = librosa.load("../music/Acorde_Do_Mayor.wav")
fig, ax = plt.subplots(figsize=(16,4))
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)
img = display.specshow(D, x_axis='time',
                               sr=sr, ax=ax,y_axis='linear')
ax.set_ylim(0,1800)
ax.set(title='Acorde Do Mayor')
ax.grid()

# %%
y
# Out:
# array([ 1.1268995e-04, -5.4256794e-05,  6.4709384e-05, ...,
#         1.6337037e-06,  4.5116449e-05,  0.0000000e+00], dtype=float32)
